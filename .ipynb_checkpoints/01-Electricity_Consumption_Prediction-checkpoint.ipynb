# %% [markdown]
# # ELECTRICITY CONSUMPTION PREDICTION
# ## => TIME SERIES
#
# ---
#
# ![](https://images.unsplash.com/photo-1487875961445-47a00398c267?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&auto=format&fit=crop&w=1650&q=80)
# Photo by [Jason Blackeye](https://unsplash.com/photos/nyL-rzwP-Mk)

# %% [markdown]
# # Context
#
# ---
#
# The project is about explore time series data in several ways and build forecasts for the electricity consumption.
#
# # Content
#
# ---
#
# The data is extracted from Open Power System Data ([OPSD](https://open-power-system-data.org/)) for Germany.
# The data set includes daily electricity consumption, wind power production, and solar power production between 2006 and 2017.
#
# - Date — The date (yyyy-mm-dd format)
# - Consumption — Electricity consumption in GWh
# - Wind — Wind power production in GWh
# - Solar — Solar power production in GWh
# - Wind+Solar — Sum of wind and solar power production in GWh
#
# # Sections
#
# ---
#
# 1. **Data Exploration**
# 2. **Modelling & Prediction** (decomposition, linear regression, SARIMAX)

# %%
# Data Exploration
import numpy as np
import pandas as pd

#Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.ndimage.interpolation import shift


# Modelling & Prediction
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression
import warnings
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %% [markdown]
# # 1. Data Exploration

# %%
df = pd.read_csv("src/opsd_germany_daily.csv", parse_dates=['Date'], index_col='Date')

# %%
df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  4383 non-null   float64
#  1   Wind         2920 non-null   float64
#  2   Solar        2188 non-null   float64
#  3   Wind+Solar   2187 non-null   float64
# dtypes: float64(4)
# memory usage: 171.2 KB

# %% [markdown]
# Then, make sure to transform the dates into datetime format in pandas :

# %%
# Transform the dates into datetime format

df.index = pd.to_datetime(df.index)

# %%
df.index
# Out:
# DatetimeIndex(['2006-01-01', '2006-01-02', '2006-01-03', '2006-01-04',
#                '2006-01-05', '2006-01-06', '2006-01-07', '2006-01-08',
#                '2006-01-09', '2006-01-10',
#                ...
#                '2017-12-22', '2017-12-23', '2017-12-24', '2017-12-25',
#                '2017-12-26', '2017-12-27', '2017-12-28', '2017-12-29',
#                '2017-12-30', '2017-12-31'],
#               dtype='datetime64[ns]', name='Date', length=4383, freq=None)

# %%
plt.figure(figsize=(14,10))
plt.plot(df["Consumption"], label="Consumption", linewidth=0.5)
plt.plot(df["Wind+Solar"], label="Wind+Solar", linewidth=0.5)

plt.title("Electricity consumption and production comparison in Germany between 2012 and 2017")
plt.legend()
plt.show()

# %% [markdown]
# We can also avoid plotting lines and simply plot dots for the consumption :

# %%
plt.figure(figsize=(14,10))
plt.plot(df['Consumption'], label="Consumption", linewidth=0.5, linestyle = "None", marker='.')
plt.title("Daily electricity consumption in Germany between 2006 and 2017")
plt.legend()
plt.show()

# %% [markdown]
# And plot the production over time :

# %%
plt.figure(figsize=(12,8))
plt.plot(df['Wind'], linewidth = 0.5, linestyle = "None", marker='.', label="Wind")
plt.plot(df['Solar'], linewidth = 0.5, label="Solar")
plt.title("Solar production over time")
plt.legend()
plt.show()

# %% [markdown]
# **Interesting insights:**
#
# - The consumption is much higher than the production. This implies that the main source of electricity consumption for German does not come from wind or sun. However, we can notice a correlative increase in these two types of energy over time. It can be assumed that this trend will continue to grow in coming years.
#
# - We can see a correlation between consumption and production : more consumption and production in winter time, and less in summer. The production and the consumption are both seasonal.
#
# - We have no overall production data before 2012.

# %%
plt.figure(figsize=(12,8))
plt.plot(df["2012"]["Consumption"])
plt.plot(df["2012"]["Wind+Solar"])

plt.title("Electricity consumption and production comparison in 2012 in Germany")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# It confirms the trend : more consumption in winter time, and less in summer. We can then zoom on a given month :

# %%
plt.figure(figsize=(12,8))
plt.plot(df["2012-05"]["Consumption"], label="Consumption")
plt.plot(df["2012-05"]["Wind+Solar"], label="Wind+Solar")

plt.title("Electricity consumption and production comparison in May, 2012 in Germany")
plt.legend()
plt.show()

# %% [markdown]
# When zooming on a month, we oberve another seasonality. There seems to be days of the week in which people consume less. For example, here's what happens when we highlight Sundays :

# %%
plt.figure(figsize=(14,10))
plt.plot(df["2013-03"]["Consumption"], label="Consumption")
plt.plot(df["2013-03"][df["2013-03"].index.dayofweek==6]["Consumption"], label="Sundays", linestyle="None", marker="o", color="red")

plt.title("Electricity consumption on Sundays in march 2013 in Germany")
plt.legend()
plt.show()

# %% [markdown]
# People consume less on weekends and more during the week.

# %%
# new columns 'year' and 'month'

df["Year"] = df.index.year
df["Month"] = [d.strftime('%b') for d in df.index]

df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  Year Month
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN  2006   Jan
# 2006-01-02     1380.521   NaN    NaN         NaN  2006   Jan
# 2006-01-03     1442.533   NaN    NaN         NaN  2006   Jan
# 2006-01-04     1457.217   NaN    NaN         NaN  2006   Jan
# 2006-01-05     1477.131   NaN    NaN         NaN  2006   Jan

# %%
# Boxplot year

plt.figure(figsize=(20,10))
sns.boxplot(x=df["Year"], y=df["Consumption"], data=df)
plt.title("Consumption in Germany by year between 2006 and 2017")
# Out:
# Text(0.5, 1.0, 'Consumption in Germany by year between 2006 and 2017')

# %%
# Boxplot month

plt.figure(figsize=(20,10))
sns.boxplot(x=df["Month"], y=df["Consumption"], data=df)
plt.title("Consumption in Germany by month between 2006 and 2017")
# Out:
# Text(0.5, 1.0, 'Consumption in Germany by month between 2006 and 2017')

# %% [markdown]
# As we see previously, the consumption is smaller in Summer, although the variance is quite large.

# %%
# Fill missing values

df.isna().sum()
# Out:
# Consumption       0
# Wind           1463
# Solar          2195
# Wind+Solar     2196
# Year              0
# Month             0
# dtype: int64

# %%
# plot Solar

plt.figure(figsize=(12,8))
plt.plot(df["Solar"].bfill(axis=0), label="Solar")
plt.show()

# %%
df_clean = df.dropna()

# %%
df_clean
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Year Month
# Date
# 2012-01-01    948.12800  227.465   6.587     234.052  2012   Jan
# 2012-01-02   1269.58100  207.327   6.574     213.901  2012   Jan
# 2012-01-03   1334.74500  473.468  24.679     498.147  2012   Jan
# 2012-01-04   1347.13600  499.804  14.681     514.485  2012   Jan
# 2012-01-05   1376.65800  523.851   5.071     528.922  2012   Jan
# ...                 ...      ...     ...         ...   ...   ...
# 2017-12-27   1263.94091  394.507  16.530     411.037  2017   Dec
# 2017-12-28   1299.86398  506.424  14.162     520.586  2017   Dec
# 2017-12-29   1295.08753  584.277  29.854     614.131  2017   Dec
# 2017-12-30   1215.44897  721.247   7.467     728.714  2017   Dec
# 2017-12-31   1107.11488  721.176  19.980     741.156  2017   Dec
#
# [2187 rows x 6 columns]

# %%
# Correlation between consumption and overall production

plt.figure(figsize=(12,8))
plt.scatter(df_clean["Consumption"], df_clean["Wind+Solar"], s=2)
plt.show()

# %%
df_clean["Consumption"].corr(df_clean["Wind+Solar"])
# Out:
# 0.02764784385924092

# %%
# Correlation between solar production and wind production

plt.figure(figsize=(12,8))
plt.scatter(df_clean["Solar"], df_clean["Wind"], s=2)
plt.show()

# %%
df_clean["Solar"].corr(df_clean["Wind"])
# Out:
# -0.30883182959773414

# %%
# Correlation between consumption and wind production

plt.figure(figsize=(12,8))
plt.scatter(df_clean["Consumption"], df_clean["Wind"], s=2)
plt.show()

# %%
df_clean["Consumption"].corr(df_clean["Wind"])
# Out:
# 0.1330759524174559

# %%
# Correlation between consumption and solar production
plt.figure(figsize=(12,8))
plt.scatter(df_clean["Consumption"], df_clean["Solar"], s=2)
plt.show()

# %%
df_clean["Consumption"].corr(df_clean["Solar"])
# Out:
# -0.2795427318582823

# %% [markdown]
# # 2. Modelling & Prediction

# %%
# Autocorrelation and partial autocorrelation of the consumption

fig, axes = plt.subplots(1, 2, figsize=(15,8))

fig = sm.graphics.tsa.plot_acf(df['Consumption'], lags=365, ax=axes[0])
fig = sm.graphics.tsa.plot_pacf(df['Consumption'], lags=365, ax=axes[1])

# %% [markdown]
# There seems to ba a quite strong autocorrelation over time between the current values and the values 365 days ago, meaning that there is a cyclical effect in the consumption.

# %%
result = adfuller(df['Consumption'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -6.239148
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# The series is stationary according to the ADFuller test.
#
# We could try a de-trending in order help our future model to be more precise. We could also remove the seasonality in the time series.

# %%
X = np.array(range(len(df['Consumption'])))
y = df['Consumption']

reg = LinearRegression().fit(X.reshape(-1,1), y)
pred_lin = reg.predict(X.reshape(-1,1))

# %%
a_1,b_1 = np.polyfit(np.log(X+1), y, 1)
a_2,b_2 = np.polyfit(X+1, np.log(y), 1)

# %%
pred_log = a_1 * np.log(X+1) + b_1
pred_exp = np.exp(b_2) + np.exp( (X+1) * a_2)

# %%
plt.plot(df['Consumption'].values)

# %%
plt.figure(figsize=(12,8))
plt.plot(df['Consumption'].values,  label="Consumption", alpha=0.7)
plt.plot(pred_lin, label="linear trend")
plt.plot(pred_log, label="log trend")
plt.plot(pred_exp, label="exp trend")
plt.legend()
plt.show()

# %% [markdown]
# There seems to be no clear trend pattern. We could consier skipping the de-trending.

# %%
# log transform 

plt.plot(np.log(df['Consumption'].values))

# %%
series = np.log(df['Consumption'].values)

# %%
# Remove seasonality

series = shift(series, 365, cval=np.NaN)
series = series[np.isfinite(series)]

# %%
plt.figure(figsize=(12,8))
plt.plot(series, label="linear trend")
plt.show()

# %% [markdown]
# We have removed most of the trend here, and it seems like we remain with a stationary series.

# %%
result = adfuller(series)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -6.135816
# p-value: 0.000000
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# Removing the trend did not improve anything. We will stay with the initial series.

# %%
# Automatic Decomposition

decomposition = seasonal_decompose(series, freq=365, extrapolate_trend='freq')
# Out:
# /home/mona_lisa/.pyenv/versions/3.7.6/envs/vivadata/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead

# %% [markdown]
# We set the frequency to 365 in this case since we observe a recurrent pattern over 365 days.

# %%
series = series[-800:]

# %%
# Moving Average (MA) processes

warnings.filterwarnings('ignore')
size = int(len(series) * 0.80)
train, test = series[0:size], series[size:len(series)]
history = [x for x in train]
predictions = []

# %%
for t in range(len(test)):
    model = ARMA(history, order=(0,2))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(yhat)

# %%
plt.figure(figsize=(12,8))
plt.plot(test, label="Test")
plt.plot(np.array(predictions).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
# Zoom on the prediction :

plt.figure(figsize=(12,8))
plt.plot(test[:30], label="Test")
plt.plot(np.array(predictions[:30]).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
mean_squared_error(test, predictions)
# Out:
# 0.013971603348227321

# %% [markdown]
# There is some lag in the prediction, an we mis-understand the magnitude and the changes.

# %%
# Auto Regressive (AR) processes

size = int(len(series) * 0.80)
train, test = series[0:size], series[size:len(series)]
history = [x for x in train]
predictions = []

for t in range(len(test)):
    model = ARMA(history, order=(2,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(yhat)

# %%
plt.figure(figsize=(12,8))
plt.plot(test, label="Test")
plt.plot(np.array(predictions).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(test[:30], label="Test")
plt.plot(np.array(predictions[:30]).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
mean_squared_error(test, predictions)
# Out:
# 0.014023936976603191

# %% [markdown]
# The AR model is not performing well.

# %%
# Auto Regressive Moving Average (ARMA) processes

from statsmodels.tsa.arima_model import ARMA

size = int(len(series) * 0.80)
train, test = series[0:size], series[size:len(series)]
history = [x for x in train]
predictions = []

for t in range(len(test)):
    model = ARMA(history, order=(1,1))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(yhat)

# %%
plt.figure(figsize=(12,8))
plt.plot(test, label="Test")
plt.plot(np.array(predictions).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(test[:100], label="Test")
plt.plot(np.array(predictions[:100]).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
mean_squared_error(test, predictions)
# Out:
# 0.013967596961975895

# %% [markdown]
# We improved the Mean Squared Error just a little.

# %%
# Auto Regressive Integrated Moving Average (ARIMA) processes

size = int(len(series) * 0.80)
train, test = series[:size], series[size:]
history = [x for x in train]
predictions = []

for t in range(len(test)):
    model = ARIMA(history, order=(1,1,1))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(yhat)

# %%
plt.figure(figsize=(12,8))
plt.plot(test, label="Test")
plt.plot(np.array(predictions).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(test[:50], label="Test")
plt.plot(np.array(predictions[:50]).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
mean_squared_error(test, predictions)
# Out:
# 0.01905157613474294

# %%
# Seasonal Autoregressive Integrated Moving-Average (SARIMA) process

size = int(len(series) * 0.80)
train, test = series[0:size], series[size:len(series)]
history = [x for x in train]
predictions = list()

for t in range(len(test)):
    model = SARIMAX(history, order=(1, 1, 1), seasonal_order=(1, 1, 1, 7))
    model_fit = model.fit(disp=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(yhat)

# %%
plt.figure(figsize=(12,8))
plt.plot(test, label="Test")
plt.plot(np.array(predictions).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(test[:50], label="Test")
plt.plot(np.array(predictions[:50]).reshape(1,-1)[0], color='red',alpha=0.5, label="Pred")
plt.legend()
plt.show()

# %%
mean_squared_error(test, predictions)
# Out:
# 0.008964438413297806
